# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
bank_dataframe = pd.DataFrame(pd.read_csv("bank-additional-full.csv", sep=';'))

# %%
bank_dataframe.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic.4y       no      no   no  telephone
# 1   57   services  married  high.school  unknown      no   no  telephone
# 2   37   services  married  high.school       no     yes   no  telephone
# 3   40     admin.  married     basic.6y       no      no   no  telephone
# 4   56   services  married  high.school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# 0          93.994          -36.4      4.857       5191.0  no
# 1          93.994          -36.4      4.857       5191.0  no
# 2          93.994          -36.4      4.857       5191.0  no
# 3          93.994          -36.4      4.857       5191.0  no
# 4          93.994          -36.4      4.857       5191.0  no
#
# [5 rows x 21 columns]

# %% [markdown]
# * Consumer confidence is an economic indicator that measures the degree of optimism that consumers feel about the overall state of the economy and their personal financial situation.
# * The 3-month Euribor interest rate is the interest rate at which a selection of European banks lend each other funds denominated in euros and whose loans have a maturity of 3 months.

# %%
bank_dataframe.shape
# Out:
# (41188, 21)

# %%
bank_dataframe.dtypes
# Out:
# age                 int64
# job                object
# marital            object
# education          object
# default            object
# housing            object
# loan               object
# contact            object
# month              object
# day_of_week        object
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome           object
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# y                  object
# dtype: object

# %%
bank_dataframe.describe(include = "all")
# Out:
#                 age     job  marital          education default housing  \
# count   41188.00000   41188    41188              41188   41188   41188
# unique          NaN      12        4                  8       3       3
# top             NaN  admin.  married  university.degree      no     yes
# freq            NaN   10422    24928              12168   32588   21576
# mean       40.02406     NaN      NaN                NaN     NaN     NaN
# std        10.42125     NaN      NaN                NaN     NaN     NaN
# min        17.00000     NaN      NaN                NaN     NaN     NaN
# 25%        32.00000     NaN      NaN                NaN     NaN     NaN
# 50%        38.00000     NaN      NaN                NaN     NaN     NaN
# 75%        47.00000     NaN      NaN                NaN     NaN     NaN
# max        98.00000     NaN      NaN                NaN     NaN     NaN
#
#          loan   contact  month day_of_week  ...      campaign         pdays  \
# count   41188     41188  41188       41188  ...  41188.000000  41188.000000
# unique      3         2     10           5  ...           NaN           NaN
# top        no  cellular    may         thu  ...           NaN           NaN
# freq    33950     26144  13769        8623  ...           NaN           NaN
# mean      NaN       NaN    NaN         NaN  ...      2.567593    962.475454
# std       NaN       NaN    NaN         NaN  ...      2.770014    186.910907
# min       NaN       NaN    NaN         NaN  ...      1.000000      0.000000
# 25%       NaN       NaN    NaN         NaN  ...      1.000000    999.000000
# 50%       NaN       NaN    NaN         NaN  ...      2.000000    999.000000
# 75%       NaN       NaN    NaN         NaN  ...      3.000000    999.000000
# max       NaN       NaN    NaN         NaN  ...     56.000000    999.000000
#
#             previous     poutcome  emp.var.rate  cons.price.idx  \
# count   41188.000000        41188  41188.000000    41188.000000
# unique           NaN            3           NaN             NaN
# top              NaN  nonexistent           NaN             NaN
# freq             NaN        35563           NaN             NaN
# mean        0.172963          NaN      0.081886       93.575664
# std         0.494901          NaN      1.570960        0.578840
# min         0.000000          NaN     -3.400000       92.201000
# 25%         0.000000          NaN     -1.800000       93.075000
# 50%         0.000000          NaN      1.100000       93.749000
# 75%         0.000000          NaN      1.400000       93.994000
# max         7.000000          NaN      1.400000       94.767000
#
#         cons.conf.idx     euribor3m   nr.employed      y
# count    41188.000000  41188.000000  41188.000000  41188
# unique            NaN           NaN           NaN      2
# top               NaN           NaN           NaN     no
# freq              NaN           NaN           NaN  36548
# mean       -40.502600      3.621291   5167.035911    NaN
# std          4.628198      1.734447     72.251528    NaN
# min        -50.800000      0.634000   4963.600000    NaN
# 25%        -42.700000      1.344000   5099.100000    NaN
# 50%        -41.800000      4.857000   5191.000000    NaN
# 75%        -36.400000      4.961000   5228.100000    NaN
# max        -26.900000      5.045000   5228.100000    NaN
#
# [11 rows x 21 columns]

# %%
df_check = bank_dataframe.describe(include = 'all')

df_check.loc['dtype'] = bank_dataframe.dtypes
df_check.loc['size'] = len(bank_dataframe)
df_check.loc['% count'] = bank_dataframe.isnull().mean()

# %%
df_check
# Out:
#              age     job  marital          education default housing    loan  \
# count      41188   41188    41188              41188   41188   41188   41188
# unique       NaN      12        4                  8       3       3       3
# top          NaN  admin.  married  university.degree      no     yes      no
# freq         NaN   10422    24928              12168   32588   21576   33950
# mean     40.0241     NaN      NaN                NaN     NaN     NaN     NaN
# std      10.4212     NaN      NaN                NaN     NaN     NaN     NaN
# min           17     NaN      NaN                NaN     NaN     NaN     NaN
# 25%           32     NaN      NaN                NaN     NaN     NaN     NaN
# 50%           38     NaN      NaN                NaN     NaN     NaN     NaN
# 75%           47     NaN      NaN                NaN     NaN     NaN     NaN
# max           98     NaN      NaN                NaN     NaN     NaN     NaN
# dtype      int64  object   object             object  object  object  object
# size       41188   41188    41188              41188   41188   41188   41188
# % count        0       0        0                  0       0       0       0
#
#           contact   month day_of_week  ... campaign    pdays  previous  \
# count       41188   41188       41188  ...    41188    41188     41188
# unique          2      10           5  ...      NaN      NaN       NaN
# top      cellular     may         thu  ...      NaN      NaN       NaN
# freq        26144   13769        8623  ...      NaN      NaN       NaN
# mean          NaN     NaN         NaN  ...  2.56759  962.475  0.172963
# std           NaN     NaN         NaN  ...  2.77001  186.911  0.494901
# min           NaN     NaN         NaN  ...        1        0         0
# 25%           NaN     NaN         NaN  ...        1      999         0
# 50%           NaN     NaN         NaN  ...        2      999         0
# 75%           NaN     NaN         NaN  ...        3      999         0
# max           NaN     NaN         NaN  ...       56      999         7
# dtype      object  object      object  ...    int64    int64     int64
# size        41188   41188       41188  ...    41188    41188     41188
# % count         0       0           0  ...        0        0         0
#
#             poutcome emp.var.rate cons.price.idx cons.conf.idx euribor3m  \
# count          41188        41188          41188         41188     41188
# unique             3          NaN            NaN           NaN       NaN
# top      nonexistent          NaN            NaN           NaN       NaN
# freq           35563          NaN            NaN           NaN       NaN
# mean             NaN    0.0818855        93.5757      -40.5026   3.62129
# std              NaN      1.57096        0.57884        4.6282   1.73445
# min              NaN         -3.4         92.201         -50.8     0.634
# 25%              NaN         -1.8         93.075         -42.7     1.344
# 50%              NaN          1.1         93.749         -41.8     4.857
# 75%              NaN          1.4         93.994         -36.4     4.961
# max              NaN          1.4         94.767         -26.9     5.045
# dtype         object      float64        float64       float64   float64
# size           41188        41188          41188         41188     41188
# % count            0            0              0             0         0
#
#         nr.employed       y
# count         41188   41188
# unique          NaN       2
# top             NaN      no
# freq            NaN   36548
# mean        5167.04     NaN
# std         72.2515     NaN
# min          4963.6     NaN
# 25%          5099.1     NaN
# 50%            5191     NaN
# 75%          5228.1     NaN
# max          5228.1     NaN
# dtype       float64  object
# size          41188   41188
# % count           0       0
#
# [14 rows x 21 columns]

# %% [markdown]
# Firstly, to lighten the dataset, we are going to create a subset with the customers' information features only

# %%
bank_dataframe_customer_info = bank_dataframe[list(bank_dataframe.loc[:, "age" : "loan"]) + ["y"]]

# %%
bank_dataframe_customer_info
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          y
# 0       no
# 1       no
# 2       no
# 3       no
# 4       no
# ...    ...
# 41183  yes
# 41184   no
# 41185   no
# 41186  yes
# 41187   no
#
# [41188 rows x 8 columns]

# %% [markdown]
# For further use, we are going to create two other subsets with the current and previous campaign data and social and economic data

# %%
bank_dataframe_campaign = bank_dataframe.loc[:, "contact" : "poutcome"]

# %%
bank_dataframe_se_context = bank_dataframe.loc[:, "emp.var.rate" : "nr.employed"]

# %%
bank_dataframe_customer_info.describe(include = "all")
# Out:
#                 age     job  marital          education default housing  \
# count   41188.00000   41188    41188              41188   41188   41188
# unique          NaN      12        4                  8       3       3
# top             NaN  admin.  married  university.degree      no     yes
# freq            NaN   10422    24928              12168   32588   21576
# mean       40.02406     NaN      NaN                NaN     NaN     NaN
# std        10.42125     NaN      NaN                NaN     NaN     NaN
# min        17.00000     NaN      NaN                NaN     NaN     NaN
# 25%        32.00000     NaN      NaN                NaN     NaN     NaN
# 50%        38.00000     NaN      NaN                NaN     NaN     NaN
# 75%        47.00000     NaN      NaN                NaN     NaN     NaN
# max        98.00000     NaN      NaN                NaN     NaN     NaN
#
#          loan      y
# count   41188  41188
# unique      3      2
# top        no     no
# freq    33950  36548
# mean      NaN    NaN
# std       NaN    NaN
# min       NaN    NaN
# 25%       NaN    NaN
# 50%       NaN    NaN
# 75%       NaN    NaN
# max       NaN    NaN

# %%
bank_dataframe_customer_info.dtypes
# Out:
# age           int64
# job          object
# marital      object
# education    object
# default      object
# housing      object
# loan         object
# y            object
# dtype: object

# %% [markdown]
# All features, excepting Age, have categorical data.
